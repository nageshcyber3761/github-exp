# %%
t=6,7,8
type(t)
# Out:
# tuple

# %%
s={}
type(s)
# Out:
# dict

# %%
s={89,90,6,'p',788888,4555,(8,99)}
set[0]
# Out:
# set[0]

# %%
s = {0, 0, 9}
s.add([6, 7, 8])   
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 s = {0, 0, 9}
# ----> 2 s.add([6, 7, 8])
#       3 print(s)
#
# TypeError: unhashable type: 'list'

# %%
s = {0, 0, 9}
s.add((6, 7, 8))
print(s)
# Out:
# {0, 9, (6, 7, 8)}

# %%
s = {0, 0, 9}
s.update([6, 7, 8])
print(s)
# Out:
# {0, 6, 7, 8, 9}

# %%
s={5,8,9}
s.remove(5)
s
# Out:
# {8, 9}

# %%
s={5,8,9}
s.discard(80)
s
# Out:
# {5, 8, 9}

# %%
s={5,8,9}
s.pop()
s
# Out:
# {5, 9}

# %%
l={44,55,66}
l.pop()
# Out:
# 66
